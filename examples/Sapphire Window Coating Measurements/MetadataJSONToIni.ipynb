# %% [markdown]
# ## MetadataJSONToIni
#
# This notebook converts the JSON metadata file from the initial sapphire coating attenuator measurement to a set of .ini sequences to be used with the GUI/state-machine to automate further transmission measurements.

# %%
import json
import configparser

# %%
with open('metadata.json', 'r') as f:
    Metadata = json.load(f)
Metadata = Metadata['measurements']

# %%
Metadata
# Out:
# [{'file-name': 'data\\2021-05-24_0.csv',
#   'sample-frequency': 500,
#   'sample-time': 1000,
#   'type': 'labjack noise',
#   'description': 'single-ended w/ bnc to alligator clip input to labjack',
#   'attenuators': None,
#   'monochromator': {'grating': None, 'osf': None, 'wavelength': None},
#   'lock-in': {'time constant': None,
#    'sensitivity': None,
#    'chop frequency': None},
#   'light-source': 'Thorlabs SLS203L',
#   'date': '05-24'},
#  {'file-name': 'data\\2021-05-24_1.csv',
#   'sample-frequency': 500,
#   'sample-time': 1000,
#   'type': 'labjack noise',
#   'description': 'Single ended w/ labjack input shorted to ground',
#   'attenuators': None,
#   'monochromator': {'grating': None, 'osf': None, 'wavelength': None},
#   'lock-in': {'time constant': None,
#    'sensitivity': None,
#    'chop frequency': None},
#   'light-source': 'Thorlabs SLS203L',
#   'date': '05-24'},
#  {'file-name': 'data\\2021-05-24_2.csv',
#   'sample-frequency': 500,
# ...
